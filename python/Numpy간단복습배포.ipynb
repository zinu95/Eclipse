# %% [markdown]
# ## Numpy를 익혀보자!

# %% [markdown]
# -  가장 먼저 해야 할 일!!!

# %%
import numpy as np

# %% [markdown]
# #### 1. 다음과 같은 array 배열을 만들고 크기, 개수, 차원을 확인해주세요.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 2. 다음과 같은 배열을 만들고, 배열의 크기를 다시 지정해주세요.
# - numpy함수 사용할 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. 위의 배열을(2번문제) 인덱싱 / 슬라이싱을 통해 다음 값들을 가져와 주세요.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### 4.  다음 \'달러\'로 된 배열 값을 \'원\' 단위로 환산해 \'won\'변수에 담아주세요 (단, 환율은 달러당 1200입니다)

# %%
dollar = np.array([12, 100, 1, 23, 5])
dollar
# Out:
# array([ 12, 100,   1,  23,   5])

# %% [markdown]
# #### 5. 위 배열(2번문제)에서 30보다 큰 값들만 뽑아주세요
# - Boolean!!!
# - 여기는 보너스 문제! 어려우시면 넘어가셔도 됩니다!

# %% [markdown]
# - numpy와 친해지고 익숙해지자! 라는 의도로 복습 겸 드려봤습니다!
# - '함수를 외운다'라기 보다 이런 기능을 제공하는구나~ 를 알고, 필요할 때 찾아보시면 되기 때문에 부담 없이 오늘 배운 부분 다시 복습한다 생각해주시면 되겠습니다~
# - 불리언 인덱싱까지 가볍게 봐주세요 수고하셨습니다~~:-D
